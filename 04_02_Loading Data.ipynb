# %% [markdown]
# dataset의 모든 데이터를 이용하는것은 현실적으로 불가능하다.
#
# * Minibatch Gradient Descent
#
#  dataset을 여러개의 minibatch로 쪼개어 학습하는 방식
#  업데이트의 주기는 빠르지만 전체 data가 아니므로 model이 잘못된 방향으로 학습될 우려가 있음

# %%
"""
pytorch dataset은 pytorch에서 제공하는 module로 이를 이용해 새로운 class를 만들어
새로운 dataset 생성 가능.
"""

import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import Dataset

class CustomDataset(Dataset):
    def __init__(self):
        self.x_data = ([[73, 80, 75],
                        [93, 88, 93],
                        [89, 91, 90],
                        [96, 98, 100],
                        [73, 66, 70]])
        self.y_data = ([[152], [185], [180], [196], [142]])
    
    # 이 dataset의 총 data 수
    def __len__(self):
        return len(self.x_data)
    
    # 어떠한 index idx를 받았을 때, 그에 상응하는 입출력 data 반환
    def __getitem__(self, idx):
        x = torch.FloatTensor(self.x_data[idx])
        y = torch.FloatTensor(self.y_data[idx])
        
        return x, y

class MultivariateLinearRegressionModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(3, 1)
        
    def forward(self, x):
        return self.linear(x)


model = MultivariateLinearRegressionModel()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-5)    
    
dataset = CustomDataset()



from torch.utils.data import DataLoader

#batch_size -> 각 minibatch의 크기. 통상적으로 2의 제곱수를 선정
#shuffle -> Epoch마다 dataset을 섞어서 data가 학습되는 순서를 바꾼다
dataloader = DataLoader(
    dataset,
    batch_size=2,
    shuffle=True,
)


nb_epochs = 100
for epoch in range(nb_epochs + 1):
    #enumerate(dataloader) -> minibatch index와 data를 get
    for batch_idx, samples in enumerate(dataloader):
        x_train, y_train = samples
        # H(x) 계산
        prediction = model(x_train)
        
        # cost 계산
        cost = F.mse_loss(prediction, y_train)
        
        # cost로 H(x) 개선
        optimizer.zero_grad()
        cost.backward()
        optimizer.step()
        
        # len(dataloader) 한 epoch당 minibatch의 갯수
        print('Epoch {:4d}/{} Batch {}/{} Cost: {:.6f}'.format(
            epoch, nb_epochs, batch_idx+1, len(dataloader), cost.item()
        ))
# Out:
# Epoch    0/100 Batch 1/3 Cost: 40347.250000
# Epoch    0/100 Batch 2/3 Cost: 11923.226562
# Epoch    0/100 Batch 3/3 Cost: 5438.209473
# Epoch    1/100 Batch 1/3 Cost: 946.091675
# Epoch    1/100 Batch 2/3 Cost: 521.021667
# Epoch    1/100 Batch 3/3 Cost: 35.041321
# Epoch    2/100 Batch 1/3 Cost: 51.326241
# Epoch    2/100 Batch 2/3 Cost: 16.774363
# Epoch    2/100 Batch 3/3 Cost: 0.288585
# Epoch    3/100 Batch 1/3 Cost: 8.112513
# Epoch    3/100 Batch 2/3 Cost: 3.876615
# Epoch    3/100 Batch 3/3 Cost: 1.311349
# Epoch    4/100 Batch 1/3 Cost: 3.626662
# Epoch    4/100 Batch 2/3 Cost: 3.984306
# Epoch    4/100 Batch 3/3 Cost: 2.010333
# Epoch    5/100 Batch 1/3 Cost: 4.065892
# Epoch    5/100 Batch 2/3 Cost: 3.615770
# Epoch    5/100 Batch 3/3 Cost: 0.087096
# Epoch    6/100 Batch 1/3 Cost: 0.697109
# Epoch    6/100 Batch 2/3 Cost: 4.386429
# Epoch    6/100 Batch 3/3 Cost: 4.667066
# Epoch    7/100 Batch 1/3 Cost: 2.585189
# Epoch    7/100 Batch 2/3 Cost: 4.670607
# Epoch    7/100 Batch 3/3 Cost: 6.462035
# Epoch    8/100 Batch 1/3 Cost: 3.081695
# Epoch    8/100 Batch 2/3 Cost: 2.367682
# Epoch    8/100 Batch 3/3 Cost: 4.699493
# Epoch    9/100 Batch 1/3 Cost: 1.024526
# Epoch    9/100 Batch 2/3 Cost: 7.374710
# Epoch    9/100 Batch 3/3 Cost: 3.290413
# Epoch   10/100 Batch 1/3 Cost: 1.519750
# Epoch   10/100 Batch 2/3 Cost: 8.501266
# Epoch   10/100 Batch 3/3 Cost: 0.454435
# Epoch   11/100 Batch 1/3 Cost: 2.996172
# Epoch   11/100 Batch 2/3 Cost: 2.168419
# Epoch   11/100 Batch 3/3 Cost: 4.849659
# Epoch   12/100 Batch 1/3 Cost: 3.267767
# Epoch   12/100 Batch 2/3 Cost: 2.971508
# Epoch   12/100 Batch 3/3 Cost: 3.927456
# Epoch   13/100 Batch 1/3 Cost: 0.902472
# Epoch   13/100 Batch 2/3 Cost: 4.333554
# Epoch   13/100 Batch 3/3 Cost: 4.839987
# Epoch   14/100 Batch 1/3 Cost: 3.797811
# Epoch   14/100 Batch 2/3 Cost: 1.724891
# Epoch   14/100 Batch 3/3 Cost: 3.709515
# Epoch   15/100 Batch 1/3 Cost: 2.665764
# Epoch   15/100 Batch 2/3 Cost: 3.771417
# Epoch   15/100 Batch 3/3 Cost: 2.382684
# Epoch   16/100 Batch 1/3 Cost: 3.811733
# Epoch   16/100 Batch 2/3 Cost: 2.231605
# Epoch   16/100 Batch 3/3 Cost: 4.080910
# Epoch   17/100 Batch 1/3 Cost: 3.944253
# Epoch   17/100 Batch 2/3 Cost: 3.520584
# Epoch   17/100 Batch 3/3 Cost: 0.091990
# Epoch   18/100 Batch 1/3 Cost: 2.338028
# Epoch   18/100 Batch 2/3 Cost: 3.155304
# Epoch   18/100 Batch 3/3 Cost: 7.124328
# Epoch   19/100 Batch 1/3 Cost: 2.785954
# Epoch   19/100 Batch 2/3 Cost: 3.836388
# Epoch   19/100 Batch 3/3 Cost: 3.773562
# Epoch   20/100 Batch 1/3 Cost: 3.320852
# Epoch   20/100 Batch 2/3 Cost: 3.735348
# Epoch   20/100 Batch 3/3 Cost: 0.675719
# Epoch   21/100 Batch 1/3 Cost: 2.052824
# Epoch   21/100 Batch 2/3 Cost: 3.518998
# Epoch   21/100 Batch 3/3 Cost: 6.737516
# Epoch   22/100 Batch 1/3 Cost: 1.854009
# Epoch   22/100 Batch 2/3 Cost: 5.938945
# Epoch   22/100 Batch 3/3 Cost: 2.624285
# Epoch   23/100 Batch 1/3 Cost: 3.386024
# Epoch   23/100 Batch 2/3 Cost: 3.670208
# Epoch   23/100 Batch 3/3 Cost: 2.201376
# Epoch   24/100 Batch 1/3 Cost: 3.589283
# Epoch   24/100 Batch 2/3 Cost: 2.999706
# Epoch   24/100 Batch 3/3 Cost: 6.150076
# Epoch   25/100 Batch 1/3 Cost: 2.942372
# Epoch   25/100 Batch 2/3 Cost: 2.197670
# Epoch   25/100 Batch 3/3 Cost: 5.700579
# Epoch   26/100 Batch 1/3 Cost: 1.611094
# Epoch   26/100 Batch 2/3 Cost: 5.491664
# Epoch   26/100 Batch 3/3 Cost: 4.029412
# Epoch   27/100 Batch 1/3 Cost: 0.344263
# Epoch   27/100 Batch 2/3 Cost: 3.953233
# Epoch   27/100 Batch 3/3 Cost: 6.367121
# Epoch   28/100 Batch 1/3 Cost: 1.762774
# Epoch   28/100 Batch 2/3 Cost: 5.953801
# Epoch   28/100 Batch 3/3 Cost: 2.644147
# Epoch   29/100 Batch 1/3 Cost: 3.799607
# Epoch   29/100 Batch 2/3 Cost: 0.507670
# Epoch   29/100 Batch 3/3 Cost: 6.947056
# Epoch   30/100 Batch 1/3 Cost: 1.893455
# Epoch   30/100 Batch 2/3 Cost: 5.109762
# Epoch   30/100 Batch 3/3 Cost: 3.875736
# Epoch   31/100 Batch 1/3 Cost: 1.104852
# Epoch   31/100 Batch 2/3 Cost: 5.181951
# Epoch   31/100 Batch 3/3 Cost: 4.168424
# Epoch   32/100 Batch 1/3 Cost: 1.482304
# Epoch   32/100 Batch 2/3 Cost: 3.192793
# Epoch   32/100 Batch 3/3 Cost: 4.909860
# Epoch   33/100 Batch 1/3 Cost: 3.702159
# Epoch   33/100 Batch 2/3 Cost: 2.693280
# Epoch   33/100 Batch 3/3 Cost: 2.699015
# Epoch   34/100 Batch 1/3 Cost: 0.382246
# Epoch   34/100 Batch 2/3 Cost: 3.870310
# Epoch   34/100 Batch 3/3 Cost: 6.182586
# Epoch   35/100 Batch 1/3 Cost: 1.642835
# Epoch   35/100 Batch 2/3 Cost: 3.011984
# Epoch   35/100 Batch 3/3 Cost: 5.064423
# Epoch   36/100 Batch 1/3 Cost: 3.406541
# Epoch   36/100 Batch 2/3 Cost: 1.619483
# Epoch   36/100 Batch 3/3 Cost: 5.464877
# Epoch   37/100 Batch 1/3 Cost: 2.672111
# Epoch   37/100 Batch 2/3 Cost: 6.812943
# Epoch   37/100 Batch 3/3 Cost: 0.080932
# Epoch   38/100 Batch 1/3 Cost: 2.484418
# Epoch   38/100 Batch 2/3 Cost: 3.537177
# Epoch   38/100 Batch 3/3 Cost: 5.591302
# Epoch   39/100 Batch 1/3 Cost: 1.623887
# Epoch   39/100 Batch 2/3 Cost: 3.755171
# Epoch   39/100 Batch 3/3 Cost: 3.097581
# Epoch   40/100 Batch 1/3 Cost: 3.097285
# Epoch   40/100 Batch 2/3 Cost: 3.554920
# Epoch   40/100 Batch 3/3 Cost: 2.243322
# Epoch   41/100 Batch 1/3 Cost: 0.343287
# Epoch   41/100 Batch 2/3 Cost: 4.437074
# Epoch   41/100 Batch 3/3 Cost: 4.714986
# Epoch   42/100 Batch 1/3 Cost: 2.999334
# Epoch   42/100 Batch 2/3 Cost: 3.551091
# Epoch   42/100 Batch 3/3 Cost: 0.507365
# Epoch   43/100 Batch 1/3 Cost: 2.013020
# Epoch   43/100 Batch 2/3 Cost: 3.326721
# Epoch   43/100 Batch 3/3 Cost: 6.593413
# Epoch   44/100 Batch 1/3 Cost: 2.987847
# Epoch   44/100 Batch 2/3 Cost: 2.912613
# Epoch   44/100 Batch 3/3 Cost: 4.351836
# Epoch   45/100 Batch 1/3 Cost: 2.913482
# Epoch   45/100 Batch 2/3 Cost: 1.621611
# Epoch   45/100 Batch 3/3 Cost: 5.041305
# Epoch   46/100 Batch 1/3 Cost: 3.339556
# Epoch   46/100 Batch 2/3 Cost: 3.489316
# Epoch   46/100 Batch 3/3 Cost: 0.103001
# Epoch   47/100 Batch 1/3 Cost: 2.199667
# Epoch   47/100 Batch 2/3 Cost: 3.027915
# Epoch   47/100 Batch 3/3 Cost: 6.817122
# Epoch   48/100 Batch 1/3 Cost: 1.845142
# Epoch   48/100 Batch 2/3 Cost: 5.581717
# Epoch   48/100 Batch 3/3 Cost: 2.542180
# Epoch   49/100 Batch 1/3 Cost: 3.129410
# Epoch   49/100 Batch 2/3 Cost: 3.818538
# Epoch   49/100 Batch 3/3 Cost: 0.086198
# Epoch   50/100 Batch 1/3 Cost: 2.203175
# Epoch   50/100 Batch 2/3 Cost: 3.516276
# Epoch   50/100 Batch 3/3 Cost: 2.509635
# Epoch   51/100 Batch 1/3 Cost: 4.126594
# Epoch   51/100 Batch 2/3 Cost: 0.698955
# Epoch   51/100 Batch 3/3 Cost: 5.443210
# Epoch   52/100 Batch 1/3 Cost: 3.492178
# Epoch   52/100 Batch 2/3 Cost: 1.652786
# Epoch   52/100 Batch 3/3 Cost: 3.344105
# Epoch   53/100 Batch 1/3 Cost: 2.943867
# Epoch   53/100 Batch 2/3 Cost: 3.127579
# Epoch   53/100 Batch 3/3 Cost: 5.659776
# Epoch   54/100 Batch 1/3 Cost: 1.628517
# Epoch   54/100 Batch 2/3 Cost: 3.634224
# Epoch   54/100 Batch 3/3 Cost: 3.012504
# Epoch   55/100 Batch 1/3 Cost: 1.341311
# Epoch   55/100 Batch 2/3 Cost: 8.014566
# Epoch   55/100 Batch 3/3 Cost: 0.401940
# Epoch   56/100 Batch 1/3 Cost: 3.428709
# Epoch   56/100 Batch 2/3 Cost: 2.936719
# Epoch   56/100 Batch 3/3 Cost: 0.239806
# Epoch   57/100 Batch 1/3 Cost: 2.067363
# Epoch   57/100 Batch 2/3 Cost: 3.466733
# Epoch   57/100 Batch 3/3 Cost: 2.578167
# Epoch   58/100 Batch 1/3 Cost: 0.892169
# Epoch   58/100 Batch 2/3 Cost: 6.875266
# Epoch   58/100 Batch 3/3 Cost: 3.115762
# Epoch   59/100 Batch 1/3 Cost: 0.965870
# Epoch   59/100 Batch 2/3 Cost: 3.844459
# Epoch   59/100 Batch 3/3 Cost: 4.300231
# Epoch   60/100 Batch 1/3 Cost: 2.859217
# Epoch   60/100 Batch 2/3 Cost: 3.536040
# Epoch   60/100 Batch 3/3 Cost: 0.459965
# Epoch   61/100 Batch 1/3 Cost: 3.983279
# Epoch   61/100 Batch 2/3 Cost: 3.771367
# Epoch   61/100 Batch 3/3 Cost: 1.823711
# Epoch   62/100 Batch 1/3 Cost: 0.314837
# Epoch   62/100 Batch 2/3 Cost: 6.802300
# Epoch   62/100 Batch 3/3 Cost: 4.419003
# Epoch   63/100 Batch 1/3 Cost: 2.983705
# Epoch   63/100 Batch 2/3 Cost: 2.491228
# Epoch   63/100 Batch 3/3 Cost: 3.982746
# Epoch   64/100 Batch 1/3 Cost: 3.561889
# Epoch   64/100 Batch 2/3 Cost: 2.756663
# Epoch   64/100 Batch 3/3 Cost: 2.520573
# Epoch   65/100 Batch 1/3 Cost: 1.172365
# Epoch   65/100 Batch 2/3 Cost: 3.909434
# Epoch   65/100 Batch 3/3 Cost: 5.198812
# Epoch   66/100 Batch 1/3 Cost: 3.644365
# Epoch   66/100 Batch 2/3 Cost: 2.963993
# Epoch   66/100 Batch 3/3 Cost: 0.596861
# Epoch   67/100 Batch 1/3 Cost: 2.023324
# Epoch   67/100 Batch 2/3 Cost: 3.695640
# Epoch   67/100 Batch 3/3 Cost: 5.130291
# Epoch   68/100 Batch 1/3 Cost: 1.532260
# Epoch   68/100 Batch 2/3 Cost: 2.937115
# Epoch   68/100 Batch 3/3 Cost: 4.285752
# Epoch   69/100 Batch 1/3 Cost: 2.966220
# Epoch   69/100 Batch 2/3 Cost: 3.656996
# Epoch   69/100 Batch 3/3 Cost: 0.099785
# Epoch   70/100 Batch 1/3 Cost: 3.358761
# Epoch   70/100 Batch 2/3 Cost: 2.221215
# Epoch   70/100 Batch 3/3 Cost: 2.865658
# Epoch   71/100 Batch 1/3 Cost: 3.406754
# Epoch   71/100 Batch 2/3 Cost: 1.417611
# Epoch   71/100 Batch 3/3 Cost: 5.223264
# Epoch   72/100 Batch 1/3 Cost: 1.544606
# Epoch   72/100 Batch 2/3 Cost: 3.528987
# Epoch   72/100 Batch 3/3 Cost: 3.023850
# Epoch   73/100 Batch 1/3 Cost: 0.925389
# Epoch   73/100 Batch 2/3 Cost: 3.782084
# Epoch   73/100 Batch 3/3 Cost: 4.204077
# Epoch   74/100 Batch 1/3 Cost: 2.813478
# Epoch   74/100 Batch 2/3 Cost: 1.541938
# Epoch   74/100 Batch 3/3 Cost: 4.737145
# Epoch   75/100 Batch 1/3 Cost: 0.483447
# Epoch   75/100 Batch 2/3 Cost: 6.057867
# Epoch   75/100 Batch 3/3 Cost: 4.587895
# Epoch   76/100 Batch 1/3 Cost: 2.797022
# Epoch   76/100 Batch 2/3 Cost: 3.050448
# Epoch   76/100 Batch 3/3 Cost: 5.412282
# Epoch   77/100 Batch 1/3 Cost: 2.733670
# Epoch   77/100 Batch 2/3 Cost: 1.587037
# Epoch   77/100 Batch 3/3 Cost: 4.433770
# Epoch   78/100 Batch 1/3 Cost: 1.379366
# Epoch   78/100 Batch 2/3 Cost: 3.627349
# Epoch   78/100 Batch 3/3 Cost: 4.926983
# Epoch   79/100 Batch 1/3 Cost: 3.005110
# Epoch   79/100 Batch 2/3 Cost: 3.488872
# Epoch   79/100 Batch 3/3 Cost: 0.583614
# Epoch   80/100 Batch 1/3 Cost: 3.267945
# Epoch   80/100 Batch 2/3 Cost: 1.976206
# Epoch   80/100 Batch 3/3 Cost: 3.030700
# Epoch   81/100 Batch 1/3 Cost: 3.319412
# Epoch   81/100 Batch 2/3 Cost: 3.264499
# Epoch   81/100 Batch 3/3 Cost: 0.077199
# Epoch   82/100 Batch 1/3 Cost: 3.283545
# Epoch   82/100 Batch 2/3 Cost: 2.919648
# Epoch   82/100 Batch 3/3 Cost: 0.182135
# Epoch   83/100 Batch 1/3 Cost: 1.300282
# Epoch   83/100 Batch 2/3 Cost: 5.669680
# Epoch   83/100 Batch 3/3 Cost: 3.503162
# Epoch   84/100 Batch 1/3 Cost: 0.466511
# Epoch   84/100 Batch 2/3 Cost: 3.481732
# Epoch   84/100 Batch 3/3 Cost: 5.578609
# Epoch   85/100 Batch 1/3 Cost: 1.505606
# Epoch   85/100 Batch 2/3 Cost: 3.427226
# Epoch   85/100 Batch 3/3 Cost: 3.522323
# Epoch   86/100 Batch 1/3 Cost: 2.734332
# Epoch   86/100 Batch 2/3 Cost: 3.261725
# Epoch   86/100 Batch 3/3 Cost: 2.235512
# Epoch   87/100 Batch 1/3 Cost: 3.450472
# Epoch   87/100 Batch 2/3 Cost: 0.459475
# Epoch   87/100 Batch 3/3 Cost: 6.526740
# Epoch   88/100 Batch 1/3 Cost: 3.128964
# Epoch   88/100 Batch 2/3 Cost: 2.857518
# Epoch   88/100 Batch 3/3 Cost: 3.194851
# Epoch   89/100 Batch 1/3 Cost: 1.361789
# Epoch   89/100 Batch 2/3 Cost: 3.033070
# Epoch   89/100 Batch 3/3 Cost: 4.490757
# Epoch   90/100 Batch 1/3 Cost: 0.960953
# Epoch   90/100 Batch 2/3 Cost: 3.051612
# Epoch   90/100 Batch 3/3 Cost: 5.369061
# Epoch   91/100 Batch 1/3 Cost: 1.474955
# Epoch   91/100 Batch 2/3 Cost: 7.413535
# Epoch   91/100 Batch 3/3 Cost: 0.174953
# Epoch   92/100 Batch 1/3 Cost: 3.209351
# Epoch   92/100 Batch 2/3 Cost: 0.806613
# Epoch   92/100 Batch 3/3 Cost: 5.782478
# Epoch   93/100 Batch 1/3 Cost: 4.830089
# Epoch   93/100 Batch 2/3 Cost: 2.120945
# Epoch   93/100 Batch 3/3 Cost: 3.293846
# Epoch   94/100 Batch 1/3 Cost: 3.684021
# Epoch   94/100 Batch 2/3 Cost: 2.973962
# Epoch   94/100 Batch 3/3 Cost: 0.691514
# Epoch   95/100 Batch 1/3 Cost: 1.895902
# Epoch   95/100 Batch 2/3 Cost: 3.591982
# Epoch   95/100 Batch 3/3 Cost: 4.851474
# Epoch   96/100 Batch 1/3 Cost: 3.265146
# Epoch   96/100 Batch 2/3 Cost: 2.677325
# Epoch   96/100 Batch 3/3 Cost: 0.409013
# Epoch   97/100 Batch 1/3 Cost: 2.192619
# Epoch   97/100 Batch 2/3 Cost: 6.396733
# Epoch   97/100 Batch 3/3 Cost: 0.584384
# Epoch   98/100 Batch 1/3 Cost: 3.605301
# Epoch   98/100 Batch 2/3 Cost: 3.601804
# Epoch   98/100 Batch 3/3 Cost: 1.822434
# Epoch   99/100 Batch 1/3 Cost: 0.311554
# Epoch   99/100 Batch 2/3 Cost: 3.493729
# Epoch   99/100 Batch 3/3 Cost: 5.873611
# Epoch  100/100 Batch 1/3 Cost: 3.225787
# Epoch  100/100 Batch 2/3 Cost: 3.754048
# Epoch  100/100 Batch 3/3 Cost: 4.549931
